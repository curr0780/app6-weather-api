# %%
import pandas as pd
df = pd.read_csv("dictionary.csv")

# %%
df
# Out:
#                             word  \
# 0      abandoned industrial site
# 1              abandoned vehicle
# 2                 abiotic factor
# 3                    access road
# 4              access to the sea
# ...                          ...
# 49532                     casing
# 49533                     facing
# 49534                     lining
# 49535         assumption of Mary
# 49536               auscultation
#
#                                               definition
# 0      Site that cannot be used for any purpose, bein...
# 1      A vehicle that has been discarded in the envir...
# 2      Physical, chemical and other non-living enviro...
# 3      Any street or narrow stretch of paved surface ...
# 4      The ability to bring goods to and from a port ...
# ...                                                  ...
# 49532  Something put around something else, usually i...
# 49533  Something put around something else, usually i...
# ...

# %%
df['word']
# Out:
# 0        abandoned industrial site
# 1                abandoned vehicle
# 2                   abiotic factor
# 3                      access road
# 4                access to the sea
#                    ...
# 49532                       casing
# 49533                       facing
# 49534                       lining
# 49535           assumption of Mary
# 49536                 auscultation
# Name: word, Length: 49537, dtype: object

# %%
df['definition']
# Out:
# 0        Site that cannot be used for any purpose, bein...
# 1        A vehicle that has been discarded in the envir...
# 2        Physical, chemical and other non-living enviro...
# 3        Any street or narrow stretch of paved surface ...
# 4        The ability to bring goods to and from a port ...
#                                ...
# 49532    Something put around something else, usually i...
# 49533    Something put around something else, usually i...
# 49534    Something put around something else, usually i...
# 49535    Catholic holiday on August 15, remembering the...
# 49536    Listening to the heart and lungs using a steth...
# Name: definition, Length: 49537, dtype: object

# %%
df.columns
# Out:
# Index(['word', 'definition'], dtype='object')

# %%
def1 = df.loc[df['word'] == 'milk']['definition']
def2 = df.loc[df['word'] == 'milk']['definition'].iloc[0]

print(type(def1))
print(f"def1 = {def1}\n")
print(type(def2))
print(f"def2 = {def2}\n")
# Out:
# <class 'pandas.core.series.Series'>
# def1 = 1471    1. The whitish fluid secreted by the mammary g...
# Name: definition, dtype: object
#
# <class 'str'>
# def2 = 1. The whitish fluid secreted by the mammary gland for the nourishment of the young; composed of carbohydrates, proteins, fats, mineral salts, vitamins, and antibodies.
# 2. To draw milk from (a mammal, especially a cow).

# %%
print(def1)
print(def1.index)
print("\n")
print(def1.values)
print(def1.tolist())
# Out:
# 1471    1. The whitish fluid secreted by the mammary g...
# Name: definition, dtype: object
# Index([1471], dtype='int64')
#
#
# ['1. The whitish fluid secreted by the mammary gland for the nourishment of the young; composed of carbohydrates, proteins, fats, mineral salts, vitamins, and antibodies.\n2. To draw milk from (a mammal, especially a cow).\n']
# ['1. The whitish fluid secreted by the mammary gland for the nourishment of the young; composed of carbohydrates, proteins, fats, mineral salts, vitamins, and antibodies.\n2. To draw milk from (a mammal, especially a cow).\n']

# %%
df.iloc[49536].squeeze()
# Out:
# word                                               auscultation
# definition    Listening to the heart and lungs using a steth...
# Name: 49536, dtype: object
